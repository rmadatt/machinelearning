# %% [markdown]
# <a href="https://colab.research.google.com/github/rmadatt/machinelearning/blob/main/01_tokenization_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install required libraries
# !pip install spacy transformers

#Download spaCy's small English model
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 118.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Input sentence
text = "I ate cheese."

# Parse the sentence
doc = nlp(text)

# Display tokens and their attributes
for token in doc:
    print(f"Token: {token.text}, POS: {token.pos_}")
# Out:
# Token: I, POS: PRON
# Token: ate, POS: VERB
# Token: cheese, POS: NOUN
# Token: ., POS: PUNCT

# %%
from transformers import BertTokenizer, BertModel
import torch

# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

# Tokenize and convert to IDs
inputs = tokenizer(text, return_tensors="pt")
print("Token IDs:", inputs["input_ids"])

# Get embeddings
with torch.no_grad():
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state

# Display vector for each token
for i, token_id in enumerate(inputs["input_ids"][0]):
    token = tokenizer.convert_ids_to_tokens(int(token_id))
    vector = embeddings[0][i]
    print(f"Token: {token}, Vector (first 5 dims): {vector[:5]}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Token IDs: tensor([[ 101, 1045, 8823, 8808, 1012,  102]])
# Token: [CLS], Vector (first 5 dims): tensor([-0.1399,  0.0521, -0.7348, -0.0912, -0.6013])
# ...

# %% [markdown]
# # Emotional resonance log
# reflection = "Today, the word 'cheese' felt oddly comforting — a soft node in my archive."
# print(reflection)
